# %%
import pandas_datareader as pdr
import pandas as pd
import yfinance as yf
import datetime as datetime

# %%
data=yf.download('TSLA',start='2000-1-1')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-07-17  286.630005  292.230011  283.570007  290.380005  290.380005
# 2023-07-18  290.149994  295.260010  286.010010  293.339996  293.339996
# 2023-07-19  296.040009  299.290009  289.519989  291.260010  291.260010
# 2023-07-20  279.559998  280.929993  261.200012  262.899994  262.899994
# 2023-07-21  268.000000  268.000000  255.800003  260.019989  260.019989
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3288 entries, 2010-06-29 to 2023-07-21
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3288 non-null   float64
#  1   High       3288 non-null   float64
#  2   Low        3288 non-null   float64
#  3   Close      3288 non-null   float64
#  4   Adj Close  3288 non-null   float64
#  5   Volume     3288 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 179.8 KB

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3288.000000  3288.000000  3288.000000  3288.000000  3288.000000
# mean     64.601207    66.051690    63.030371    64.579912    64.579912
# std      97.984532   100.222977    95.499607    97.896335    97.896335
# min       1.076000     1.108667     0.998667     1.053333     1.053333
# 25%       9.898334    10.028167     9.617500     9.841333     9.841333
# 50%      16.626667    16.857000    16.400000    16.605333    16.605333
# 75%      51.893501    53.361165    50.467833    51.698998    51.698998
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              Volume
# count  3.288000e+03
# mean   9.611860e+07
# std    8.123903e+07
# min    1.777500e+06
# 25%    4.440112e+07
# 50%    7.892235e+07
# 75%    1.230431e+08
# max    9.140820e+08

# %%
data['High'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data['High'].plot(xlim=['2020-01-01','2022-01-01'],ylim=[0,600],figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#add colour
data['High'].plot(xlim=['2020-01-01','2022-01-01'],ylim=[0,600],figsize=(12,4),c='red',ls='--')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2023-07-10', '2023-07-11', '2023-07-12', '2023-07-13',
#                '2023-07-14', '2023-07-17', '2023-07-18', '2023-07-19',
#                '2023-07-20', '2023-07-21'],
#               dtype='datetime64[ns]', name='Date', length=3288, freq=None)

# %%
data.loc['2015-01-1':'2020-01-01']
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2015-01-02  14.858000  14.883333  14.217333  14.620667  14.620667   71466000
# 2015-01-05  14.303333  14.433333  13.810667  14.006000  14.006000   80527500
# 2015-01-06  14.004000  14.280000  13.614000  14.085333  14.085333   93928500
# 2015-01-07  14.223333  14.318667  13.985333  14.063333  14.063333   44526000
# 2015-01-08  14.187333  14.253333  14.000667  14.041333  14.041333   51637500
# ...               ...        ...        ...        ...        ...        ...
# 2019-12-24  27.890667  28.364668  27.512667  28.350000  28.350000  120820500
# 2019-12-26  28.527332  28.898666  28.423332  28.729334  28.729334  159508500
# 2019-12-27  29.000000  29.020666  28.407333  28.691999  28.691999  149185500
# 2019-12-30  28.586000  28.600000  27.284000  27.646667  27.646667  188796000
# 2019-12-31  27.000000  28.086000  26.805332  27.888666  27.888666  154285500
#
# [1258 rows x 6 columns]

# %%
share_open=data.loc['2015-01-1':'2020-01-01']['Open']  #play with date index
index=data.loc['2015-01-1':'2020-01-01'].index
index,share_open
# Out:
# (DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                 '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                 '2015-01-14', '2015-01-15',
#                 ...
#                 '2019-12-17', '2019-12-18', '2019-12-19', '2019-12-20',
#                 '2019-12-23', '2019-12-24', '2019-12-26', '2019-12-27',
#                 '2019-12-30', '2019-12-31'],
#                dtype='datetime64[ns]', name='Date', length=1258, freq=None),
#  Date
#  2015-01-02    14.858000
#  2015-01-05    14.303333
#  2015-01-06    14.004000
#  2015-01-07    14.223333
#  2015-01-08    14.187333
#                  ...
#  2019-12-24    27.890667
#  2019-12-26    28.527332
#  2019-12-27    29.000000
#  2019-12-30    28.586000
#  2019-12-31    27.000000
#  Name: Open, Length: 1258, dtype: float64)

# %%
figure,axis=plt.subplots()
plt.tight_layout()
figure.autofmt_xdate()#this prevent overlapping
plt.plot(index,share_open)

# %%
data=data.reset_index() #here date will become colums
data
# Out:
#       index       Date        Open        High         Low       Close  \
# 0         0 2010-06-29    1.266667    1.666667    1.169333    1.592667
# 1         1 2010-06-30    1.719333    2.028000    1.553333    1.588667
# 2         2 2010-07-01    1.666667    1.728000    1.351333    1.464000
# 3         3 2010-07-02    1.533333    1.540000    1.247333    1.280000
# 4         4 2010-07-06    1.333333    1.333333    1.055333    1.074000
# ...     ...        ...         ...         ...         ...         ...
# 3283   3283 2023-07-17  286.630005  292.230011  283.570007  290.380005
# 3284   3284 2023-07-18  290.149994  295.260010  286.010010  293.339996
# 3285   3285 2023-07-19  296.040009  299.290009  289.519989  291.260010
# 3286   3286 2023-07-20  279.559998  280.929993  261.200012  262.899994
# 3287   3287 2023-07-21  268.000000  268.000000  255.800003  260.019989
#
#        Adj Close     Volume
# 0       1.592667  281494500
# 1       1.588667  257806500
# ...

# %%
data=data.set_index(data['Date'])
data
# Out:
#             index       Date        Open        High         Low       Close  \
# Date
# 2010-06-29      0 2010-06-29    1.266667    1.666667    1.169333    1.592667
# 2010-06-30      1 2010-06-30    1.719333    2.028000    1.553333    1.588667
# 2010-07-01      2 2010-07-01    1.666667    1.728000    1.351333    1.464000
# 2010-07-02      3 2010-07-02    1.533333    1.540000    1.247333    1.280000
# 2010-07-06      4 2010-07-06    1.333333    1.333333    1.055333    1.074000
# ...           ...        ...         ...         ...         ...         ...
# 2023-07-17   3283 2023-07-17  286.630005  292.230011  283.570007  290.380005
# 2023-07-18   3284 2023-07-18  290.149994  295.260010  286.010010  293.339996
# 2023-07-19   3285 2023-07-19  296.040009  299.290009  289.519989  291.260010
# 2023-07-20   3286 2023-07-20  279.559998  280.929993  261.200012  262.899994
# 2023-07-21   3287 2023-07-21  268.000000  268.000000  255.800003  260.019989
#
#              Adj Close     Volume
# ...

# %%
data.drop(columns=['index'],inplace=True)

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-07-17  286.630005  292.230011  283.570007  290.380005  290.380005
# 2023-07-18  290.149994  295.260010  286.010010  293.339996  293.339996
# 2023-07-19  296.040009  299.290009  289.519989  291.260010  291.260010
# 2023-07-20  279.559998  280.929993  261.200012  262.899994  262.899994
# 2023-07-21  268.000000  268.000000  255.800003  260.019989  260.019989
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %%
from datetime import datetime
datetime(2022,11,11)
# Out:
# datetime.datetime(2022, 11, 11, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 7, 24, 10, 33, 18, 355672)

# %%
#Time resampling

# %%
data.resample(rule='A').min()    #this will show the min value of open high low close of that particular year
#rule=A mean year end frequency
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    1.076000    1.108667    0.998667    1.053333    1.053333
# 2011-12-31    1.452000    1.484667    1.407333    1.455333    1.455333
# 2012-12-31    1.774667    1.790000    1.509333    1.519333    1.519333
# 2013-12-31    2.205333    2.225333    2.140667    2.194000    2.194000
# 2014-12-31    9.366667    9.800000    9.111333    9.289333    9.289333
# 2015-12-31   12.388667   12.619333   12.093333   12.333333   12.333333
# 2016-12-31    9.488000   10.331333    9.403333    9.578000    9.578000
# 2017-12-31   14.316667   14.688667   14.064000   14.466000   14.466000
# 2018-12-31   16.851999   17.355333   16.306000   16.704000   16.704000
# 2019-12-31   12.073333   12.445333   11.799333   11.931333   11.931333
# 2020-12-31   24.980000   26.990667   23.367332   24.081333   24.081333
# 2021-12-31  184.183334  188.736664  179.830002  187.666672  187.666672
# ...

# %%
data.resample(rule='A').max()    #this will show the max value of open high low close of that particular year
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-12-31    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-12-31    2.546000    2.663333    2.474000    2.534000    2.534000
# 2013-12-31   12.930667   12.966667   12.558000   12.891333   12.891333
# 2014-12-31   19.177999   19.427999   18.693333   19.069332   19.069332
# 2015-12-31   18.680000   19.110001   18.420000   18.817333   18.817333
# 2016-12-31   17.763332   17.955999   16.967333   17.694668   17.694668
# 2017-12-31   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# ...

# %%
plt.plot(data.resample(rule='A').max()['Open'])

# %%
data.resample(rule='B').min()    # Rule B means half yearly
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-05         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2023-07-17  286.630005  292.230011  283.570007  290.380005  290.380005
# 2023-07-18  290.149994  295.260010  286.010010  293.339996  293.339996
# 2023-07-19  296.040009  299.290009  289.519989  291.260010  291.260010
# 2023-07-20  279.559998  280.929993  261.200012  262.899994  262.899994
# 2023-07-21  268.000000  268.000000  255.800003  260.019989  260.019989
#
#                  Volume
# Date
# 2010-06-29  281494500.0
# 2010-06-30  257806500.0
# 2010-07-01  123282000.0
# ...

# %%
data.resample(rule='QS').max()    #QS means quarterly frequency
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-04-01    1.719333    2.028000    1.553333    1.592667    1.592667
# 2010-07-01    1.666667    1.728000    1.408667    1.465333    1.465333
# 2010-10-01    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-01-01    1.906000    1.914000    1.870000    1.896667    1.896667
# 2011-04-01    2.006667    2.100000    1.970000    2.009333    2.009333
# 2011-07-01    1.992667    2.029333    1.934000    1.982000    1.982000
# 2011-10-01    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-01-01    2.546000    2.663333    2.474000    2.529333    2.529333
# 2012-04-01    2.488667    2.564667    2.444667    2.534000    2.534000
# 2012-07-01    2.333333    2.400000    2.260000    2.397333    2.397333
# 2012-10-01    2.350667    2.386667    2.330000    2.352000    2.352000
# 2013-01-01    2.630000    2.666667    2.609333    2.632000    2.632000
# ...

# %%
#plotting
data['Open'].resample(rule='BA').max().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#to get monthly frequency
data['Open'].resample(rule='M').max()  #rule M monthly
# Out:
# Date
# 2010-06-30      1.719333
# 2010-07-31      1.666667
# 2010-08-31      1.463333
# 2010-09-30      1.476667
# 2010-10-31      1.426000
#                  ...
# 2023-03-31    206.210007
# 2023-04-30    199.910004
# 2023-05-31    200.100006
# 2023-06-30    275.130005
# 2023-07-31    296.040009
# Freq: M, Name: Open, Length: 158, dtype: float64

# %%
data.rolling(10).mean()  #Rolling Mean: The value of MovingAverage is calculated by taking average data of the time-series within k(10) periods
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29         NaN         NaN         NaN         NaN         NaN
# 2010-06-30         NaN         NaN         NaN         NaN         NaN
# 2010-07-01         NaN         NaN         NaN         NaN         NaN
# 2010-07-02         NaN         NaN         NaN         NaN         NaN
# 2010-07-06         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2023-07-17  277.150998  281.076999  273.276999  277.432001  277.432001
# 2023-07-18  278.516998  282.178000  274.367001  278.784000  278.784000
# 2023-07-19  280.238998  283.722000  275.559000  279.662000  279.662000
# 2023-07-20  280.385999  283.817999  274.391000  278.297998  278.297998
# 2023-07-21  279.342999  282.539999  272.594002  276.856998  276.856998
#
#                  Volume
# Date
# 2010-06-29          NaN
# 2010-06-30          NaN
# 2010-07-01          NaN
# ...

# %%
data.rolling(10).max() #Rolling Max: The value of max of the time-series within k(10) periods
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29         NaN         NaN         NaN         NaN         NaN
# 2010-06-30         NaN         NaN         NaN         NaN         NaN
# 2010-07-01         NaN         NaN         NaN         NaN         NaN
# 2010-07-02         NaN         NaN         NaN         NaN         NaN
# 2010-07-06         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2023-07-17  286.630005  292.230011  283.570007  290.380005  290.380005
# 2023-07-18  290.149994  295.260010  286.010010  293.339996  293.339996
# 2023-07-19  296.040009  299.290009  289.519989  293.339996  293.339996
# 2023-07-20  296.040009  299.290009  289.519989  293.339996  293.339996
# 2023-07-21  296.040009  299.290009  289.519989  293.339996  293.339996
#
#                  Volume
# Date
# 2010-06-29          NaN
# 2010-06-30          NaN
# 2010-07-01          NaN
# ...

# %%
data['rolling_open_30days']=data['Open'].rolling(window=30,min_periods=1).mean()  #e calulate moving avg for 30 days 
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-07-17  286.630005  292.230011  283.570007  290.380005  290.380005
# 2023-07-18  290.149994  295.260010  286.010010  293.339996  293.339996
# 2023-07-19  296.040009  299.290009  289.519989  291.260010  291.260010
# 2023-07-20  279.559998  280.929993  261.200012  262.899994  262.899994
# 2023-07-21  268.000000  268.000000  255.800003  260.019989  260.019989
#
#                Volume  rolling_open_30days
# Date
# 2010-06-29  281494500             1.266667
# ...

# %%
data[['Open','rolling_open_30days']].plot(xlim=['2018-01-01','2022-01-01']).figsize=(25,15)

# %%
data['rolling_open_50days']=data['Open'].rolling(window=50,min_periods=1).mean()  #e calulate moving avg for 30 days 
data['rolling_open_10days']=data['Open'].rolling(window=10,min_periods=1).mean()  #e calulate moving avg for 30 days 
data
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-07-17  286.630005  292.230011  283.570007  290.380005  290.380005
# 2023-07-18  290.149994  295.260010  286.010010  293.339996  293.339996
# 2023-07-19  296.040009  299.290009  289.519989  291.260010  291.260010
# 2023-07-20  279.559998  280.929993  261.200012  262.899994  262.899994
# 2023-07-21  268.000000  268.000000  255.800003  260.019989  260.019989
#
#                Volume  rolling_open_30days  rolling_open_50days  \
# Date
# ...

# %%
data[['Open','rolling_open_30days','rolling_open_50days','rolling_open_10days']].plot(xlim=['2021-01-01','2022-01-01']).figsize=(25,15)

# %%
# for cumulative moving average expand

(data['Open'].expanding().mean()).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Exponential moving aveage
#smothing_factor=0.1(alpha)
data['EMA_0.1']=data['Open'].ewm(alpha=0.1,adjust=False).mean()

# %%
data[['Open','EMA_0.1']].plot(xlim=['2021-01-01','2022-01-01'])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#the EMV are smoothining factor which smothens the curve without lags

# %%
df=pd.read_csv("C:/Users/HP/Downloads/Time series.csv")

# %%
df.head()
# Out:
#      Month  Thousands of Passengers
# 0  1949-01                    112.0
# 1  1949-02                    118.0
# 2  1949-03                    132.0
# 3  1949-04                    129.0
# 4  1949-05                    121.0

# %%
import numpy as np
import statsmodels.api as sms

# %%
df.tail()
# Out:
#        Month  Thousands of Passengers
# 139  1960-08                    606.0
# 140  1960-09                    508.0
# 141  1960-10                    461.0
# 142  1960-11                    390.0
# 143  1960-12                    432.0

# %%
df.dropna(inplace=True)

# %%
df['Month']=pd.to_datetime(df['Month'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Month                    144 non-null    datetime64[ns]
#  1   Thousands of Passengers  144 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 3.4 KB

# %%
df=df.set_index(['Month'])

# %%
df
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                    112.0
# 1949-02-01                    118.0
# 1949-03-01                    132.0
# 1949-04-01                    129.0
# 1949-05-01                    121.0
# ...                             ...
# 1960-08-01                    606.0
# 1960-09-01                    508.0
# 1960-10-01                    461.0
# 1960-11-01                    390.0
# 1960-12-01                    432.0
#
# [144 rows x 1 columns]

# %%
df.plot()  #since its a seasonal data,we use dickyfuller test
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def adf_test(series):
    result=adfuller(series)
    print('ADF statistics: {}'.format(result[0]))
    print('P-value: {}'.format(result[1]))
    
    if result[1]<=0.05:
        print('reject null hypothesis')
        
    else:
        print('accept null hypothesis')

# %%
adf_test(df['Thousands of Passengers'])
# Out:
# ADF statistics: 0.8153688792060423
# P-value: 0.9918802434376409
# accept null hypothesis

# %%
#sice it is not stateoney we do differencing   

df['first_difference']=df['Thousands of Passengers']-df['Thousands of Passengers'].shift(1)   #shift(1) will move one step back

# %%
df
# Out:
#             Thousands of Passengers  first_difference
# Month
# 1949-02-01                    118.0               6.0
# 1949-03-01                    132.0              14.0
# 1949-04-01                    129.0              -3.0
# 1949-05-01                    121.0              -8.0
# 1949-06-01                    135.0              14.0
# ...                             ...               ...
# 1960-08-01                    606.0             -16.0
# 1960-09-01                    508.0             -98.0
# 1960-10-01                    461.0             -47.0
# 1960-11-01                    390.0             -71.0
# 1960-12-01                    432.0              42.0
#
# [143 rows x 2 columns]

# %%
df.dropna(inplace=True)

# %%
adf_test(df['first_difference'])  #now also its not stationary data,hence we do second difference
# Out:
# ADF statistics: -2.8292668241699874
# P-value: 0.05421329028382711
# accept null hypothesis

# %%
df['second_difference']=df['first_difference']-df['first_difference'].shift(1)

# %%
df.head()
# Out:
#             Thousands of Passengers  first_difference  second_difference
# Month
# 1949-02-01                    118.0               6.0                NaN
# 1949-03-01                    132.0              14.0                8.0
# 1949-04-01                    129.0              -3.0              -17.0
# 1949-05-01                    121.0              -8.0               -5.0
# 1949-06-01                    135.0              14.0               22.0

# %%
df.dropna(inplace=True)

# %%
adf_test(df['second_difference'])   #now it becomes stationary data
# Out:
# ADF statistics: -16.384231542468513
# P-value: 2.7328918500142026e-29
# reject null hypothesis

# %%
#since it is a seasonal data we have 12 months hence we have to make a 12 diffence data
df['12_difference']=df['Thousands of Passengers']-df['Thousands of Passengers'].shift(12)

# %%
adf_test(df['12_difference'].dropna())
# Out:
# ADF statistics: -3.42813913312251
# P-value: 0.010036205946729016
# reject null hypothesis

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
acf=plot_acf(df['second_difference'].dropna())
#here q=13 since no of points between 2 out band is 13

# %%
acf=plot_acf(df['12_difference'].dropna())   #here q=5 since no of points above band is 5

# %%
result=plot_pacf(df['second_difference'].dropna())
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
pacf=plot_pacf(df['12_difference'].dropna())   #here we initialy put p=2,but as per diagram p=10 no of points between outbounds
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from datetime import datetime,timedelta

# %%
train_data_end=datetime(1955,12,1)
test_data_end=datetime(1960,12,1)

# %%
train_data=df[:train_data_end]
test_data=df[train_data_end+timedelta(days=1):test_data_end]

# %%
pred_start_date=test_data.index[0]
pred_end_date=test_data.index[-1]

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
train_data.head()
# Out:
#             Thousands of Passengers  first_difference  second_difference  \
# Month
# 1949-03-01                    132.0              14.0                8.0
# 1949-04-01                    129.0              -3.0              -17.0
# 1949-05-01                    121.0              -8.0               -5.0
# 1949-06-01                    135.0              14.0               22.0
# 1949-07-01                    148.0              13.0               -1.0
#
#             12_difference
# Month
# 1949-03-01            NaN
# 1949-04-01            NaN
# 1949-05-01            NaN
# 1949-06-01            NaN
# 1949-07-01            NaN

# %%
import statsmodels.api as sm

# %%
model_arima=sm.tsa.arima.ARIMA(train_data['Thousands of Passengers'],order=(14,2,0))   #order=p value,d value(difference),q value
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
model_arima_fit=model_arima.fit()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model_arima_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   SARIMAX Results
# ...
# Dep. Variable:     Thousands of Passengers   No. Observations:                   82
# Model:                     ARIMA(14, 2, 0)   Log Likelihood                -300.638
# Date:                     Tue, 25 Jul 2023   AIC                            631.276
# Time:                             10:41:09   BIC                            667.006
# Sample:                         03-01-1949   HQIC                           645.601
#                               - 12-01-1955
# Covariance Type:                       opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.1637      0.154     -7.557      0.000      -1.466      -0.862
# ar.L2         -1.1991      0.223     -5.389      0.000      -1.635      -0.763
# ...

# %%
pred=model_arima_fit.predict(start=pred_start_date,end=pred_end_date)
residual=test_data['Thousands of Passengers']-pred

# %%
residual
# Out:
# Month
# 1956-01-01     -6.327873
# 1956-02-01     -6.920072
# 1956-03-01     13.553468
# 1956-04-01      0.574536
# 1956-05-01      2.686672
# 1956-06-01     12.805667
# 1956-07-01      6.309983
# 1956-08-01     17.558081
# 1956-09-01     -1.257776
# 1956-10-01    -14.726375
# 1956-11-01    -20.055458
# 1956-12-01    -17.078179
# 1957-01-01    -24.832571
# 1957-02-01    -26.567210
# 1957-03-01     11.899566
# 1957-04-01     -6.979411
# 1957-05-01     -7.529157
# 1957-06-01     15.672317
# 1957-07-01     16.385784
# 1957-08-01     37.964355
# 1957-09-01      4.777064
# 1957-10-01    -22.195617
# 1957-11-01    -37.831202
# 1957-12-01    -34.297839
# 1958-01-01    -46.630172
# 1958-02-01    -54.944346
# 1958-03-01    -22.278827
# 1958-04-01    -51.004297
# 1958-05-01    -45.887667
# 1958-06-01    -16.547255
# 1958-07-01      0.934832
# 1958-08-01     33.965517
# 1958-09-01    -38.380687
# 1958-10-01    -58.405641
# 1958-11-01    -84.451318
# 1958-12-01    -80.315551
# ...

# %%
model_arima_fit.resid.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
test_data['predicted_arima']=pred
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18428\931718042.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['predicted_arima']=pred

# %%
test_data[['Thousands of Passengers','predicted_arima']].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
model_sarima=sm.tsa.statespace.SARIMAX(train_data['Thousands of Passengers'],order=(3,0,5),seasonal_order=(1,1,1,12))
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
model_sarima_fit=model_sarima.fit()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model_sarima_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ...
# Dep. Variable:              Thousands of Passengers   No. Observations:                   82
# Model:             SARIMAX(3, 0, 5)x(1, 1, [1], 12)   Log Likelihood                -257.410
# Date:                              Tue, 25 Jul 2023   AIC                            536.820
# Time:                                      10:30:21   BIC                            561.553
# Sample:                                  03-01-1949   HQIC                           546.644
#                                        - 12-01-1955
# Covariance Type:                                opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1246      0.411      0.303      0.762      -0.681       0.930
# ...

# %%
pred=model_sarima_fit.predict(start=pred_start_date,end=pred_end_date)
residual=test_data['Thousands of Passengers']-pred

# %%
residual
# Out:
# Month
# 1956-01-01    -2.506808
# 1956-02-01     1.646537
# 1956-03-01     5.715180
# 1956-04-01     3.364619
# 1956-05-01     7.803804
# 1956-06-01    22.254249
# 1956-07-01    16.723805
# 1956-08-01    24.233848
# 1956-09-01     7.487561
# 1956-10-01    -6.216622
# 1956-11-01    -6.275505
# 1956-12-01    -8.224313
# 1957-01-01    -8.909806
# 1957-02-01   -11.094685
# 1957-03-01     7.475640
# 1957-04-01     0.138463
# 1957-05-01     7.266388
# 1957-06-01    31.614616
# 1957-07-01    28.908879
# 1957-08-01    47.406452
# 1957-09-01    17.872410
# 1957-10-01    -3.352059
# 1957-11-01    -9.410839
# 1957-12-01   -16.384033
# 1958-01-01   -21.919978
# 1958-02-01   -31.823823
# 1958-03-01   -24.169895
# 1958-04-01   -37.378822
# 1958-05-01   -22.053509
# 1958-06-01     7.563547
# 1958-07-01    18.052900
# 1958-08-01    48.617407
# 1958-09-01   -18.916239
# 1958-10-01   -28.301734
# 1958-11-01   -41.345705
# 1958-12-01   -52.013207
# 1959-01-01   -38.613264
# 1959-02-01   -44.376402
# ...

# %%
test_data[['Thousands of Passengers','predicted_arima']].plot()
# Out:
# <AxesSubplot:xlabel='Month'>
